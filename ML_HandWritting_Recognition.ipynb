# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/devbijoy274/AI_Implementation/blob/master/ML_HandWritting_Recognition.ipynb)

# %% [markdown]
# <img height="60px" src="https://colab.research.google.com/img/colab_favicon.ico" align="left" hspace="20px" vspace="5px">
#
# <h1>My "Hello World!" in Machine Learning !</h1>
# This is a basic handwritting gesturing project, this will walk through basics of ML and regression. For more project, find my other projects on Github!

# %%
# Tensorflow and tf.keras
import tensorflow as tf
from tensorflow import keras
print("TF Version: ", tf.__version__)
print("Keras: ",keras.__version__)

# Helper Libraries
import numpy as np
import matplotlib.pyplot as plt
# Out:
# TF Version:  1.10.0
# Keras:  2.1.6-tf

# %%
# Datasets MNIST from Keras

hand_written_mnist = keras.datasets.mnist

(train_images, train_labels), (test_images, test_labels) = hand_written_mnist.load_data()

plt.figure()
plt.imshow(train_images[1])
plt.colorbar()
plt.grid(False)

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0
class_names = ["one","two","three","four","five","six","seven","eight","nine","ten"]

plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_images[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[train_labels[i]])

# %%
# Leanrn Model and compile
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer=tf.train.AdamOptimizer(),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=6)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Test loss",test_loss)
print("Test accuracy",test_acc)
# Out:
# Epoch 1/6
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.2572 - acc: 0.9268
# Epoch 2/6
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1118 - acc: 0.9672
# Epoch 3/6
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0753 - acc: 0.9773
# Epoch 4/6
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0561 - acc: 0.9827
# Epoch 5/6
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0440 - acc: 0.9866
# Epoch 6/6
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.0344 - acc: 0.9897
# 10000/10000 [==============================] - 0s 28us/step
# Test loss 0.07420305718465242
# Test accuracy 0.9781
