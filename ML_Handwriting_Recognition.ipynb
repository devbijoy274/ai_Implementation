# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/devbijoy274/AI_Implementation/blob/master/ML_Handwriting_Recognition.ipynb)

# %% [markdown]
# <img height="60px" src="https://colab.research.google.com/img/colab_favicon.ico" align="left" hspace="20px" vspace="5px">
#
# <h1>My "Hello World!" in Machine Learning !</h1>
# This is a basic handwriting gesturing project, this will walk through basics of ML, for more details, find my other projects on Github!

# %%
# Tensorflow and tf.keras
import tensorflow as tf
from tensorflow import keras
print("TF Version: ", tf.__version__)
print("Keras: ",keras.__version__)

# Helper Libraries
import numpy as np
import matplotlib.pyplot as plt
# Out:
# TF Version:  1.10.0
# Keras:  2.1.6-tf

# %%
# Datasets MNIST from Keras

hand_written_mnist = keras.datasets.mnist

(train_images, train_labels), (test_images, test_labels) = hand_written_mnist.load_data()

plt.figure()
plt.imshow(train_images[1])
plt.colorbar()
plt.grid(False)

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0
class_names = ["zero","one","two","three","four","five","six","seven","eight","nine","ten"]

plt.figure(figsize=(10,10))
for i in range(100):
  plt.subplot(10,10,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_images[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[train_labels[i]])

# %%
# Leanrn Model and compile
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer=tf.train.AdamOptimizer(),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Test loss",test_loss)
print("Test accuracy",test_acc)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.2556 - acc: 0.9267
# Epoch 2/5
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1116 - acc: 0.9669
# Epoch 3/5
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.0767 - acc: 0.9770
# Epoch 4/5
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0577 - acc: 0.9822
# Epoch 5/5
# ...
# 10000/10000 [==============================] - 0s 27us/step
# Test loss 0.08068750098499004
# Test accuracy 0.9764

# %%
for i in range(100):
  plt.subplot(10,10,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(test_images[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[test_labels[i]])
